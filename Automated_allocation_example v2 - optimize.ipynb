# %% [markdown]
# ![Image Description](/images/Operations_Research_Methodology_Diagram.png)

# %%
#  pip install gurobipy
# pip install pulp
# Out:
#   Cell In[2], line 2
#     pip install pulp
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from datetime import datetime, timedelta, time
from pulp import (
    LpProblem,
    LpMinimize,
    LpVariable,
    lpSum,
    LpStatus,
    value,
    PULP_CBC_CMD,
)

file_path = r"/home/alvaro.berobide/Documents/Etihad/Automated Allocation Excel v7 - For tests.xlsm"
# Load data
manpower_df = pd.read_excel(file_path, sheet_name="Manpower")
flights_df = pd.read_excel(file_path, sheet_name="Flights").head(50)

# Let's handle the NaN values
manpower_df["Main Certifications"] = manpower_df["Main Certifications"].apply(
    lambda x: [] if pd.isna(x) else x
)
manpower_df["Cat-A Certifications"] = manpower_df["Cat-A Certifications"].apply(
    lambda x: [] if pd.isna(x) else x
)
# Extract certifiers, aircraft, bays, and shifts from the data
certifiers = manpower_df["Name"].unique()
aircraft_wp = flights_df["WP"].unique()
bays = flights_df["Bay"].unique()

# Create dictionaries for certifier and aircraft information
certifier_info = manpower_df.set_index("Name").to_dict("index")
aircraft_info = flights_df.set_index("WP").to_dict("index")

# Define what a long stop is, in minutes
long_stop = 5 * 60

# %%
############################ COSTS ############################


# Function to calculate movement cost (or time) between bays
# If they are of the same area (for instance, both are 600), I define the movement cost as 2 minutes per bay, with a maximum of 10 minutes
# If they are of different areas, I set the movement cost as 30 minutes
def calculate_movement_cost(bay1, bay2):
    if bay1 // 100 == bay2 // 100:
        return min(2 * abs(bay1 - bay2), 10)
    else:
        return 30

# Create a movement time matrix. This matrix will be for all the possible pairs of aircraft
movement_cost_matrix = {}
for a1 in aircraft_wp:
    for a2 in aircraft_wp:
        movement_cost_matrix[(a1, a2)] = calculate_movement_cost(
            aircraft_info[a1]["Bay"], aircraft_info[a2]["Bay"]
        )

# We can also define a cost of changing bay zones. It was 100 but i think a bit higher is better
def calculate_zone_change_cost(bay_zone_1, bay_zone_2):
    if bay_zone_1 != bay_zone_2:
        return 200
    else:
        return 0

# Costs of assigning Main Certifier, Cat-A Certifier and someone with no certifications
# The No Certifications needs to be done in order to always get a solution
def calculate_certification_cost(certifier, aircraft):
    aircraft_type = aircraft_info[aircraft]["Aircraft type"]
    main_certifications = certifier_info[certifier]["Main Certifications"]
    cat_a_certifications = certifier_info[certifier]["Cat-A Certifications"]
    if aircraft_type in main_certifications:
        return 0
    elif aircraft_type in cat_a_certifications:
        return 50
    else:
        return 100000  # Large penalty to discourage assignment

# Cost of assigning a shift leader
def calculate_shift_leader_cost(certifier):
    if certifier_info[certifier]["Type"] == "LE":
        return 100
    else:
        return 0

# Cost of assigning a quality control certifier
# As the QC is also a shift leader (is this so?), his actual cost will be the quality control cost + the shift leader cost
def calculate_quality_control_cost(certifier):
    if certifier_info[certifier]["Primary Bay Zone"] == "QC":
        return 200
    else:
        return 0

# Define the cost for assigning multiple aircraft to the same certifier. It should not grow linearly, but more exponentially
# 1 aicraft -> 50, 2 aircraft -> 150, 3 aircraft -> 300, 4 aircraft -> 500, 5 aircraft -> 750, 6 aircraft -> 1050
# def calculate_assignment_cost(num_assigned_aircraft):
#     if num_assigned_aircraft == 0:
#         return 0
#     if num_assigned_aircraft == 1:
#         return 50
#     elif num_assigned_aircraft == 2:
#         return 150
#     elif num_assigned_aircraft == 3:
#         return 300
#     elif num_assigned_aircraft == 4:
#         return 500
#     elif num_assigned_aircraft == 5:
#         return 750
#     elif num_assigned_aircraft == 6:
#         return 1050
#     else:
#         return 2000


def calculate_assignment_cost(num_assigned_aircraft):
    if num_assigned_aircraft <= 0.9:
        return 0
    elif num_assigned_aircraft <= 1.5:
        return 50
    elif num_assigned_aircraft <= 2.5:
        return 150
    elif num_assigned_aircraft <= 3.5:
        return 300
    elif num_assigned_aircraft <= 4.5:
        return 500
    elif num_assigned_aircraft <= 5.5:
        return 750
    elif num_assigned_aircraft <= 6.5:
        return 1050
    elif num_assigned_aircraft <= 7:
        return 1400
    else:
        return 2500

# Define the cost of assigning aicraft with similar departure time. If he is a Cat-A, he shouldn't be assigned to two aircrafts with close departure times
def calculate_similar_departure_time_cost(certifier, departure_time_1, departure_time_2):
    if abs(departure_time_1 - departure_time_2) < timedelta(minutes=30):
        if certifier_info[certifier]['Cat-A Certifications'] != '':
            return 1500
        else:
            return 100
    else:
        return 0

# Define the cost of assigning aicraft with similar arrival time. If he is a Cat-A, he shouldn't be assigned to two aircrafts with close arrivals
def calculate_similar_arrival_time_cost(certifier, arrival_time_1, arrival_time_2):
    if abs(arrival_time_1 - arrival_time_2) < timedelta(minutes=10):
        if certifier_info[certifier]["Cat-A Certifications"] != "":
            return 1500
        else:
            return 100
    else:
        return 0


# Define the cost of assigning aicraft looking at the times and shedules
def calculate_overlapping_time_cost(
    certifier,
    departure_time_1,
    arrival_time_1,
    departure_time_2,
    arrival_time_2,
    ground_time_1,
    ground_time_2,
):
    if ground_time_1 > long_stop or ground_time_2 > long_stop:
        return 0
    elif (arrival_time_1 < departure_time_2 and arrival_time_2 < departure_time_1) or (
        arrival_time_2 < departure_time_1 and arrival_time_1 < departure_time_2
    ):
        if certifier_info[certifier]["Cat-A Certifications"] != "":
            return 250
        else:
            return 100
    else:
        return 0


# Cost of assigning many long stops?

############################ COSTS ############################

# %%
# Initialize the problem
problem = LpProblem("Aircraft_Assignment", LpMinimize)
total_cost = 0

# Define decision variables
assignment = LpVariable.dicts("Assign", (certifiers, aircraft_wp), 0, 1, cat="Binary")

# Auxiliary variables for movement
# Maybe instead of having this variable, I can have something like: assignment[c][a1] * assignment [c][a2] for a1 in aircrafts.... with a1!=a2
movement = LpVariable.dicts(
    "Movement", (certifiers, aircraft_wp, aircraft_wp), 0, 1, cat="Binary"
)

# Calculate total costs
movement_cost_total = lpSum(
    [
        movement_cost_matrix[(a1, a2)] * movement[c][a1][a2]
        + calculate_zone_change_cost(aircraft_info[a1]["Bay"], aircraft_info[a2]["Bay"])
        * movement[c][a1][a2]
        for c in certifiers
        for a1 in aircraft_wp
        for a2 in aircraft_wp
    ]
)

similar_departure_time_cost_total = lpSum(
    [
        calculate_similar_departure_time_cost(
            c, aircraft_info[a1]["Departure time"], aircraft_info[a2]["Departure time"]
        )
        * movement[c][a1][a2]
        for a1 in aircraft_wp
        for a2 in aircraft_wp
        for c in certifiers
        if a1 != a2
    ]
)

similar_arrival_time_cost_total = lpSum(
    [
        calculate_similar_arrival_time_cost(
            c, aircraft_info[a1]["Arrival time"], aircraft_info[a2]["Arrival time"]
        )
        * movement[c][a1][a2]
        for a1 in aircraft_wp
        for a2 in aircraft_wp
        for c in certifiers
        if a1 != a2
    ]
)

# Define binary variables for assignment cost function
assignment_costs = {
    c: LpVariable.dicts(f"AssignmentCost_{c}", range(7), 0, 1, cat="Binary")
    for c in certifiers
}

# Calculate assignment costs and add them to the total cost
assignment_cost_total = lpSum(
    [
        calculate_assignment_cost(i) * assignment_costs[c][i]
        for c in certifiers
        for i in range(7)
    ]
)

for c in certifiers:
    # Ensure that exactly one cost level is selected
    problem += lpSum([assignment_costs[c][i] for i in range(7)]) == 1

    # Link assignment cost levels to the number of assigned aircraft
    problem += lpSum([assignment[c][a] for a in aircraft_wp]) == lpSum(
        [i * assignment_costs[c][i] for i in range(7)]
    )

# Add the additional cost components to the total cost
certification_shift_quality_cost_total = lpSum(
    [
        assignment[c][a]
        * (
            calculate_certification_cost(c, a)
            + calculate_shift_leader_cost(c)
            + calculate_quality_control_cost(c)
        )
        for c in certifiers
        for a in aircraft_wp
    ]
)

overlapping_time_cost_total = lpSum(
    [
        calculate_overlapping_time_cost(
            c,
            aircraft_info[a1]["Departure time"],
            aircraft_info[a1]["Arrival time"],
            aircraft_info[a2]["Departure time"],
            aircraft_info[a2]["Arrival time"],
            aircraft_info[a1]["Ground Time (minutes)"],
            aircraft_info[a2]["Ground Time (minutes)"],
        )
        * movement[c][a1][a2]
        for a1 in aircraft_wp
        for a2 in aircraft_wp
        for c in certifiers
        if a1 != a2
    ]
)

# Add all components to the total cost
total_cost = (
    movement_cost_total
    + similar_departure_time_cost_total
    + similar_arrival_time_cost_total
    + assignment_cost_total
    + overlapping_time_cost_total
    + certification_shift_quality_cost_total
)

# Add the total cost to the problem
problem += total_cost, "Minimize_Total_Cost"

# Constraints
# Each aircraft should be assigned to exactly one certifier
for a in aircraft_wp:
    problem += lpSum([assignment[c][a] for c in certifiers]) == 1

# # Certifiers should be assigned to aircraft they have certification, as Main Certification or Cat-A certification. If they don't have it, they can't be assigned
# for c in certifiers:
#     for a in aircraft_wp:
#         if (
#             aircraft_info[a]["Aircraft type"]
#             not in certifier_info[c]["Main Certifications"]
#             and aircraft_info[a]["Aircraft type"]
#             not in certifier_info[c]["Cat-A Certifications"]
#         ):
#             problem += assignment[c][a] == 0

# Add the constraint that certifiers should be assigned to aircraft in their shift range + 1 hour
for c in certifiers:
    for a in aircraft_wp:
        arrival_time = aircraft_info[a]["Arrival time"]
        departure_time = aircraft_info[a]["Departure time"]

        shift_start_buffered = certifier_info[c]["Shift Start"] - timedelta(hours=1)
        shift_end_buffered = certifier_info[c]["Shift End"] + timedelta(hours=1)

        # Check if the aircraft's arrival or departure time falls within the buffered shift range
        if not (
            shift_start_buffered <= arrival_time <= shift_end_buffered
            or shift_start_buffered <= departure_time <= shift_end_buffered
        ):
            problem += assignment[c][a] == 0

# # Certifiers should be assigned to a maximum of 2 aircraft with long layovers
# for c in certifiers:
#     problem += (
#         lpSum(
#             [
#                 assignment[c][a]
#                 for a in aircraft_wp
#                 if aircraft_info[a]["Ground Time (minutes)"] > long_stop
#             ]
#         )
#         <= 2
#     )

# Link movement variables with assignments
for c in certifiers:
    for a1 in aircraft_wp:
        for a2 in aircraft_wp:
            if a1 != a2:
                problem += (
                    movement[c][a1][a2] >= assignment[c][a1] + assignment[c][a2] - 1
                )
                problem += movement[c][a1][a2] <= assignment[c][a1]
                problem += movement[c][a1][a2] <= assignment[c][a2]


# Solve the problem
# solver = PULP_CBC_CMD(msg=1, timeLimit=160, presolve="on", strong=2, gapRel=0.2)
solver = PULP_CBC_CMD(msg=1, timeLimit=1200, presolve="on", strong=2, gapRel=0)
problem.solve(solver)

# Check the solution
print(f"Status: {LpStatus[problem.status]}")
total_cost_value = value(problem.objective)
print(f"Total cost: {total_cost_value}")

# Detailed cost breakdown
print("Detailed Cost Breakdown:")
movement_cost_value = value(movement_cost_total)
assignment_cost_value = value(assignment_cost_total)
certification_shift_quality_cost_value = value(certification_shift_quality_cost_total)
similar_departure_time_cost_value = value(similar_departure_time_cost_total)
similar_arrival_time_cost_value = value(similar_arrival_time_cost_total)
overlapping_time_cost_value = value(overlapping_time_cost_total)

print(f"Movement cost: {movement_cost_value}")
print(f"Assignment cost: {assignment_cost_value}")
print(
    f"Certification, shift leader, and quality control cost: {certification_shift_quality_cost_value}"
)
print(f"Similar departure time cost: {similar_departure_time_cost_value}")
print(f"Similar arrival time cost: {similar_arrival_time_cost_value}")
print(f"Overlapping time cost: {overlapping_time_cost_value}")

for c in certifiers:
    for a in aircraft_wp:
        if assignment[c][a].varValue == 1:
            print(f"Certifier {c} is assigned to Aircraft {a}")

# Print the costs and assignments
no_certification_assignments = []

for c in certifiers:
    num_aircraft_assigned = sum(assignment[c][a].varValue for a in aircraft_wp)
    assignment_cost = calculate_assignment_cost(num_aircraft_assigned)
    print(f"Certifier {c}:")
    print(f"  Number of aircraft assigned: {num_aircraft_assigned}")
    print(f"  Assignment cost: {assignment_cost}")

    movement_cost = 0
    zone_change_cost = 0
    similar_departure_time_cost = 0
    similar_arrival_time_cost = 0
    overlapping_time_cost = 0
    assigned_aircraft = [a for a in aircraft_wp if assignment[c][a].varValue == 1]

    for i in range(len(assigned_aircraft)):
        for j in range(i + 1, len(assigned_aircraft)):
            a1 = assigned_aircraft[i]
            a2 = assigned_aircraft[j]
            movement_cost += movement_cost_matrix[(a1, a2)]
            zone_change_cost += calculate_zone_change_cost(
                aircraft_info[a1]["Bay"], aircraft_info[a2]["Bay"]
            )
            similar_departure_time_cost += calculate_similar_departure_time_cost(
                c,
                aircraft_info[a1]["Departure time"],
                aircraft_info[a2]["Departure time"],
            )
            similar_arrival_time_cost += calculate_similar_arrival_time_cost(
                c, aircraft_info[a1]["Arrival time"], aircraft_info[a2]["Arrival time"]
            )
            overlapping_time_cost += calculate_overlapping_time_cost(
                c,
                aircraft_info[a1]["Departure time"],
                aircraft_info[a1]["Arrival time"],
                aircraft_info[a2]["Departure time"],
                aircraft_info[a2]["Arrival time"],
                aircraft_info[a1]["Ground Time (minutes)"],
                aircraft_info[a2]["Ground Time (minutes)"],
            )

    print(f"  Movement cost: {movement_cost}")
    print(f"  Zone change cost: {zone_change_cost}")
    print(f"  Similar departure time cost: {similar_departure_time_cost}")
    print(f"  Similar arrival time cost: {similar_arrival_time_cost}")
    print(f"  Overlapping time cost: {overlapping_time_cost}")

    certification_shift_quality_cost = sum(
        assignment[c][a].varValue
        * (
            calculate_certification_cost(c, a)
            + calculate_shift_leader_cost(c)
            + calculate_quality_control_cost(c)
        )
        for a in aircraft_wp
    )
    print(
        f"  Certification, shift leader, and quality control cost: {certification_shift_quality_cost}"
    )

    for a in assigned_aircraft:
        certification_cost = calculate_certification_cost(c, a)
        print(f"  Aircraft {a}:")
        print(f"    Certification cost: {certification_cost}")
        if certification_cost == 100000:
            no_certification_assignments.append((c, a))

# Print assignments without certifications
if no_certification_assignments:
    print("Assignments without proper certifications:")
    for certifier, aircraft in no_certification_assignments:
        print(
            f"  Certifier {certifier} is assigned to Aircraft {aircraft} without proper certification"
        )

# Print total cost
total_cost_value = value(problem.objective)
print(f"Total cost: {total_cost_value}")

# Print final assignments
for c in certifiers:
    for a in aircraft_wp:
        if assignment[c][a].varValue == 1:
            print(f"Certifier {c} is assigned to Aircraft {a}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/alvaro.berobide/.local/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/slurm-alvaro.berobide-34492/9e4ee32f92464dc98466efcd41810a5d-pulp.mps -sec 1200 -ratio 0 -presolve on -strong 2 -timeMode elapsed -branch -printingOptions all -solution /tmp/slurm-alvaro.berobide-34492/9e4ee32f92464dc98466efcd41810a5d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 176509 COLUMNS
# At line 712017 RHS
# At line 888522 BOUNDS
# At line 948691 ENDATA
# Problem MODEL has 176504 rows, 60168 columns and 414318 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1200
# ratioGap was changed from 0 to 0
# strongBranching was changed from 5 to 2
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4950 - 12.67 seconds
# Cgl0002I 594 variables fixed
# Cgl0003I 0 fixed, 0 tightened bounds, 54226 strengthened rows, 28584 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 42445 strengthened rows, 11494 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 36793 strengthened rows, 3190 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 34732 strengthened rows, 1956 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 33005 strengthened rows, 1384 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 31995 strengthened rows, 456 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 31469 strengthened rows, 124 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30778 strengthened rows, 84 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30272 strengthened rows, 42 substitutions
# Cgl0004I processed model has 103869 rows, 35938 columns (35938 integer (35938 of which binary)) and 532698 elements
# Cbc0038I Initial state - 580 integers unsatisfied sum - 84.341
# Cbc0038I Pass   1: (48.27 seconds) suminf.   31.97440 (371) obj. 1.10389e+06 iterations 2469
# Cbc0038I Pass   2: (48.51 seconds) suminf.   28.32109 (385) obj. 1.19563e+06 iterations 273
# Cbc0038I Pass   3: (48.58 seconds) suminf.   27.54154 (402) obj. 1.23625e+06 iterations 62
# Cbc0038I Pass   4: (48.72 seconds) suminf.   28.99325 (335) obj. 1.32369e+06 iterations 147
# Cbc0038I Pass   5: (48.83 seconds) suminf.   27.58000 (316) obj. 1.39374e+06 iterations 145
# Cbc0038I Pass   6: (48.95 seconds) suminf.   28.10019 (261) obj. 1.36429e+06 iterations 179
# Cbc0038I Pass   7: (49.57 seconds) suminf.   43.71230 (128) obj. 1.29093e+06 iterations 1172
# Cbc0038I Pass   8: (49.88 seconds) suminf.   31.57746 (208) obj. 1.29009e+06 iterations 832
# Cbc0038I Pass   9: (49.99 seconds) suminf.   28.72105 (248) obj. 1.29017e+06 iterations 174
# Cbc0038I Pass  10: (50.07 seconds) suminf.   27.68550 (288) obj. 1.29823e+06 iterations 118
# Cbc0038I Pass  11: (50.15 seconds) suminf.   27.28788 (253) obj. 1.31527e+06 iterations 105
# Cbc0038I Pass  12: (50.23 seconds) suminf.   27.03974 (284) obj. 1.31743e+06 iterations 84
# Cbc0038I Pass  13: (50.31 seconds) suminf.   28.03036 (279) obj. 1.35242e+06 iterations 90
# Cbc0038I Pass  14: (50.43 seconds) suminf.   25.61084 (287) obj. 1.31921e+06 iterations 149
# Cbc0038I Pass  15: (50.59 seconds) suminf.   24.90421 (243) obj. 1.3673e+06 iterations 246
# Cbc0038I Pass  16: (50.68 seconds) suminf.   24.39133 (283) obj. 1.41278e+06 iterations 100
# Cbc0038I Pass  17: (50.82 seconds) suminf.   24.93678 (224) obj. 1.40585e+06 iterations 214
# Cbc0038I Pass  18: (51.51 seconds) suminf.   47.25000 (138) obj. 1.27007e+06 iterations 1666
# Cbc0038I Pass  19: (51.77 seconds) suminf.   32.33333 (68) obj. 1.25632e+06 iterations 1294
# Cbc0038I Pass  20: (51.82 seconds) suminf.   31.33333 (66) obj. 1.30632e+06 iterations 79
# Cbc0038I Pass  21: (51.89 seconds) suminf.   28.85185 (129) obj. 1.35751e+06 iterations 182
# Cbc0038I Pass  22: (52.00 seconds) suminf.   25.40821 (219) obj. 1.33852e+06 iterations 202
# Cbc0038I Pass  23: (52.05 seconds) suminf.   25.75397 (215) obj. 1.35301e+06 iterations 63
# Cbc0038I Pass  24: (52.10 seconds) suminf.   25.40821 (218) obj. 1.33867e+06 iterations 57
# Cbc0038I Pass  25: (52.18 seconds) suminf.   23.67128 (190) obj. 1.29348e+06 iterations 146
# Cbc0038I Pass  26: (52.24 seconds) suminf.   23.52476 (201) obj. 1.29873e+06 iterations 51
# Cbc0038I Pass  27: (52.30 seconds) suminf.   23.99419 (196) obj. 1.33713e+06 iterations 123
# Cbc0038I Pass  28: (53.20 seconds) suminf.   45.51076 (202) obj. 1.35553e+06 iterations 2038
# Cbc0038I Pass  29: (53.66 seconds) suminf.   24.95833 (163) obj. 1.63879e+06 iterations 1519
# Cbc0038I Pass  30: (53.75 seconds) suminf.   24.23333 (201) obj. 1.63413e+06 iterations 192
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 34689 integers at bound fixed and 13 continuous
# Cbc0038I Full problem 103869 rows 35938 columns, reduced to 13841 rows 1212 columns
# Cbc0038I Mini branch and bound did not improve solution (53.99 seconds)
# Cbc0038I After 53.99 seconds - Feasibility pump exiting - took 6.52 seconds
# Cbc0031I 241 added rows had average density of 25.813278
# Cbc0013I At root node, 241 cuts changed objective from 4950 to 4950 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 386 row cuts average 2.0 elements, 0 column cuts (0 active)  in 15.399 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 214 row cuts average 650.5 elements, 0 column cuts (0 active)  in 1.687 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.234 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 294.0 elements, 0 column cuts (0 active)  in 0.359 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.043 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 97 row cuts average 90.6 elements, 0 column cuts (0 active)  in 1.556 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 167 row cuts average 11.6 elements, 0 column cuts (0 active)  in 124.345 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 4950 (205.51 seconds)
# Cbc0004I Integer solution of 4950 found after 18225 iterations and 92 nodes (238.61 seconds)
# Cbc0001I Search completed - best objective 4950, took 18225 iterations and 92 nodes (238.62 seconds)
# Cbc0032I Strong branching done 932 times (30888 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 45, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4950 to 4950
# Probing was tried 39 times and created 398 cuts of which 0 were active after adding rounds of cuts (15.980 seconds)
# Gomory was tried 39 times and created 287 cuts of which 0 were active after adding rounds of cuts (2.387 seconds)
# Knapsack was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.234 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# MixedIntegerRounding2 was tried 10 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.359 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.043 seconds)
# TwoMirCuts was tried 10 times and created 97 cuts of which 0 were active after adding rounds of cuts (1.556 seconds)
# ZeroHalf was tried 10 times and created 167 cuts of which 0 were active after adding rounds of cuts (124.345 seconds)
# ImplicationCuts was tried 15 times and created 102 cuts of which 0 were active after adding rounds of cuts (0.037 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4950.00000000
# Enumerated nodes:               92
# Total iterations:               18225
# Time (CPU seconds):             239.01
# Time (Wallclock seconds):       239.39
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       239.34   (Wallclock seconds):       239.73
#
# Status: Optimal
# Total cost: 4950.0
# Detailed Cost Breakdown:
# Movement cost: 7576.0
# Assignment cost: 4300.0
# Certification, shift leader, and quality control cost: 650.0
# Similar departure time cost: 18000.0
# Similar arrival time cost: 6000.0
# Overlapping time cost: 4500.0
# Certifier A.SHUAIBI is assigned to Aircraft BLR/L-150724
# Certifier SANDEEP is assigned to Aircraft XWE/L-150724
# Certifier AMIN S is assigned to Aircraft XWC/L-150724-2
# Certifier AMIN S is assigned to Aircraft XWB/L-150724
# Certifier AMIN S is assigned to Aircraft BLZ/L-150724-2
# Certifier CRAIG is assigned to Aircraft BND/L-150724
# Certifier CRAIG is assigned to Aircraft BMJ/L-150724
# Certifier CRAIG is assigned to Aircraft BMD/L-150724
# Certifier ZAHID is assigned to Aircraft EJA/L-150724-2
# Certifier ZAHID is assigned to Aircraft EIN/L-150724-4
# Certifier ADIL is assigned to Aircraft EIW/L-150724-2
# Certifier ADIL is assigned to Aircraft EIP/L-150724-3
# Certifier ADIL is assigned to Aircraft BME/L-150724
# Certifier BIJOY is assigned to Aircraft ETG/L-150724
# Certifier BIJOY is assigned to Aircraft DDC/L-150724-2
# Certifier MITSIS is assigned to Aircraft BNB/L-150724
# Certifier MITSIS is assigned to Aircraft BMH/L-150724
# Certifier NASEERUDDIN is assigned to Aircraft EIH/L-150724-3
# Certifier NASEERUDDIN is assigned to Aircraft BNF/L-150724
# Certifier NASEERUDDIN is assigned to Aircraft BMG/L-150724-2
# Certifier SUNIL D' is assigned to Aircraft ETQ/L-160724
# Certifier SUNIL D' is assigned to Aircraft ETJ/L-150724-2
# Certifier SUNIL D' is assigned to Aircraft DDB/L-160724
# Certifier OSMAN is assigned to Aircraft BMF/L-150724
# Certifier OSMAN is assigned to Aircraft BLS/L-150724
# Certifier OSMAN is assigned to Aircraft BLM/L-150724
# Certifier JAHANGIR is assigned to Aircraft ETA/L-150724
# Certifier JAHANGIR is assigned to Aircraft DDF/L-160724
# Certifier JAHANGIR is assigned to Aircraft BLU/L-150724-2
# Certifier MANI is assigned to Aircraft BMI/L-150724
# Certifier MANI is assigned to Aircraft BLK/L-150724
# Certifier MARK C. is assigned to Aircraft EIU/L-150724-3
# Certifier MARK C. is assigned to Aircraft BLW/L-150724
# Certifier MIRZA A is assigned to Aircraft XWA/L-150724
# Certifier MIRZA A is assigned to Aircraft BLT/L-150724
# Certifier KANTI is assigned to Aircraft EII/L-150724-4
# Certifier KANTI is assigned to Aircraft BNE/L-150724
# Certifier KANTI is assigned to Aircraft BLY/L-150724
# Certifier MUZAHMI is assigned to Aircraft EJA/L-150724-3
# Certifier MUZAHMI is assigned to Aircraft EIT/L-150724-2
# Certifier MUZAHMI is assigned to Aircraft EII/L-150724-3
# Certifier ALEXANDER is assigned to Aircraft EIN/L-150724-3
# Certifier SAMEER is assigned to Aircraft EIX/L-150724-3
# Certifier SAMEER is assigned to Aircraft EIA/L-150724-3
# Certifier SOROKIN is assigned to Aircraft ETP/L-150724
# Certifier SOROKIN is assigned to Aircraft ETE/L-160724
# Certifier LEWIS is assigned to Aircraft EIX/L-150724-2
# Certifier ISMAEEL is assigned to Aircraft EIV/L-150724-2
# Certifier MANSOUR is assigned to Aircraft EIY/L-150724-2
# Certifier MANSOUR is assigned to Aircraft EIS/L-150724-2
# Certifier A.OBAID:
#   Number of aircraft assigned: 0.0
#   Assignment cost: 0
#   Movement cost: 0
#   Zone change cost: 0
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
# Certifier A.SHUAIBI:
#   Number of aircraft assigned: 1.0
#   Assignment cost: 50
#   Movement cost: 0
#   Zone change cost: 0
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 100.0
#   Aircraft BLR/L-150724:
#     Certification cost: 0
# Certifier SANDEEP:
#   Number of aircraft assigned: 1.0
#   Assignment cost: 50
#   Movement cost: 0
#   Zone change cost: 0
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 100.0
#   Aircraft XWE/L-150724:
#     Certification cost: 0
# Certifier AMIN S:
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 4
#   Zone change cost: 200
#   Similar departure time cost: 1500
#   Similar arrival time cost: 0
#   Overlapping time cost: 250
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft XWC/L-150724-2:
#     Certification cost: 0
#   Aircraft XWB/L-150724:
#     Certification cost: 0
#   Aircraft BLZ/L-150724-2:
#     Certification cost: 0
# Certifier CRAIG:
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 30
#   Zone change cost: 300
#   Similar departure time cost: 1500
#   Similar arrival time cost: 0
#   Overlapping time cost: 250
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft BND/L-150724:
#     Certification cost: 0
#   Aircraft BMJ/L-150724:
#     Certification cost: 0
#   Aircraft BMD/L-150724:
#     Certification cost: 0
# Certifier ZAHID:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 10
#   Zone change cost: 100
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft EJA/L-150724-2:
#     Certification cost: 0
#   Aircraft EIN/L-150724-4:
#     Certification cost: 0
# Certifier ADIL:
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 28
#   Zone change cost: 300
#   Similar departure time cost: 1500
#   Similar arrival time cost: 0
#   Overlapping time cost: 750
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft EIW/L-150724-2:
#     Certification cost: 0
#   Aircraft EIP/L-150724-3:
#     Certification cost: 0
#   Aircraft BME/L-150724:
#     Certification cost: 0
# Certifier BIJOY:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 30
#   Zone change cost: 100
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft ETG/L-150724:
#     Certification cost: 0
#   Aircraft DDC/L-150724-2:
#     Certification cost: 0
# Certifier MITSIS:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 10
#   Zone change cost: 100
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft BNB/L-150724:
#     Certification cost: 0
#   Aircraft BMH/L-150724:
#     Certification cost: 0
# Certifier NASEERUDDIN:
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 30
#   Zone change cost: 300
#   Similar departure time cost: 1500
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft EIH/L-150724-3:
#     Certification cost: 0
#   Aircraft BNF/L-150724:
#     Certification cost: 0
#   Aircraft BMG/L-150724-2:
#     Certification cost: 0
# Certifier SUNIL D':
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 70
#   Zone change cost: 300
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft ETQ/L-160724:
#     Certification cost: 0
#   Aircraft ETJ/L-150724-2:
#     Certification cost: 0
#   Aircraft DDB/L-160724:
#     Certification cost: 0
# Certifier OSMAN:
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 30
#   Zone change cost: 300
#   Similar departure time cost: 0
#   Similar arrival time cost: 3000
#   Overlapping time cost: 250
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft BMF/L-150724:
#     Certification cost: 0
#   Aircraft BLS/L-150724:
#     Certification cost: 0
#   Aircraft BLM/L-150724:
#     Certification cost: 0
# Certifier JAHANGIR:
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 62
#   Zone change cost: 300
#   Similar departure time cost: 1500
#   Similar arrival time cost: 0
#   Overlapping time cost: 250
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft ETA/L-150724:
#     Certification cost: 0
#   Aircraft DDF/L-160724:
#     Certification cost: 0
#   Aircraft BLU/L-150724-2:
#     Certification cost: 0
# Certifier MANI:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 10
#   Zone change cost: 100
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft BMI/L-150724:
#     Certification cost: 0
#   Aircraft BLK/L-150724:
#     Certification cost: 0
# Certifier MARK C.:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 10
#   Zone change cost: 100
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft EIU/L-150724-3:
#     Certification cost: 0
#   Aircraft BLW/L-150724:
#     Certification cost: 0
# Certifier MIRZA A:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 10
#   Zone change cost: 100
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft XWA/L-150724:
#     Certification cost: 0
#   Aircraft BLT/L-150724:
#     Certification cost: 0
# Certifier KANTI:
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 28
#   Zone change cost: 300
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 250
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft EII/L-150724-4:
#     Certification cost: 0
#   Aircraft BNE/L-150724:
#     Certification cost: 0
#   Aircraft BLY/L-150724:
#     Certification cost: 0
# Certifier MUZAHMI:
#   Number of aircraft assigned: 3.0
#   Assignment cost: 300
#   Movement cost: 4
#   Zone change cost: 200
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 0.0
#   Aircraft EJA/L-150724-3:
#     Certification cost: 0
#   Aircraft EIT/L-150724-2:
#     Certification cost: 0
#   Aircraft EII/L-150724-3:
#     Certification cost: 0
# Certifier ALEXANDER:
#   Number of aircraft assigned: 1.0
#   Assignment cost: 50
#   Movement cost: 0
#   Zone change cost: 0
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 50.0
#   Aircraft EIN/L-150724-3:
#     Certification cost: 50
# Certifier SAMEER:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 10
#   Zone change cost: 100
#   Similar departure time cost: 1500
#   Similar arrival time cost: 0
#   Overlapping time cost: 250
#   Certification, shift leader, and quality control cost: 100.0
#   Aircraft EIX/L-150724-3:
#     Certification cost: 50
#   Aircraft EIA/L-150724-3:
#     Certification cost: 50
# Certifier SOROKIN:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 2
#   Zone change cost: 100
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 100.0
#   Aircraft ETP/L-150724:
#     Certification cost: 50
#   Aircraft ETE/L-160724:
#     Certification cost: 50
# Certifier LEWIS:
#   Number of aircraft assigned: 1.0
#   Assignment cost: 50
#   Movement cost: 0
#   Zone change cost: 0
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 50.0
#   Aircraft EIX/L-150724-2:
#     Certification cost: 50
# Certifier ISMAEEL:
#   Number of aircraft assigned: 1.0
#   Assignment cost: 50
#   Movement cost: 0
#   Zone change cost: 0
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 50.0
#   Aircraft EIV/L-150724-2:
#     Certification cost: 50
# Certifier MANSOUR:
#   Number of aircraft assigned: 2.0
#   Assignment cost: 150
#   Movement cost: 10
#   Zone change cost: 100
#   Similar departure time cost: 0
#   Similar arrival time cost: 0
#   Overlapping time cost: 0
#   Certification, shift leader, and quality control cost: 100.0
#   Aircraft EIY/L-150724-2:
#     Certification cost: 50
#   Aircraft EIS/L-150724-2:
#     Certification cost: 50
# Total cost: 4950.0
# Certifier A.SHUAIBI is assigned to Aircraft BLR/L-150724
# Certifier SANDEEP is assigned to Aircraft XWE/L-150724
# Certifier AMIN S is assigned to Aircraft XWC/L-150724-2
# Certifier AMIN S is assigned to Aircraft XWB/L-150724
# Certifier AMIN S is assigned to Aircraft BLZ/L-150724-2
# Certifier CRAIG is assigned to Aircraft BND/L-150724
# Certifier CRAIG is assigned to Aircraft BMJ/L-150724
# Certifier CRAIG is assigned to Aircraft BMD/L-150724
# Certifier ZAHID is assigned to Aircraft EJA/L-150724-2
# Certifier ZAHID is assigned to Aircraft EIN/L-150724-4
# Certifier ADIL is assigned to Aircraft EIW/L-150724-2
# Certifier ADIL is assigned to Aircraft EIP/L-150724-3
# Certifier ADIL is assigned to Aircraft BME/L-150724
# Certifier BIJOY is assigned to Aircraft ETG/L-150724
# Certifier BIJOY is assigned to Aircraft DDC/L-150724-2
# Certifier MITSIS is assigned to Aircraft BNB/L-150724
# Certifier MITSIS is assigned to Aircraft BMH/L-150724
# Certifier NASEERUDDIN is assigned to Aircraft EIH/L-150724-3
# Certifier NASEERUDDIN is assigned to Aircraft BNF/L-150724
# Certifier NASEERUDDIN is assigned to Aircraft BMG/L-150724-2
# Certifier SUNIL D' is assigned to Aircraft ETQ/L-160724
# Certifier SUNIL D' is assigned to Aircraft ETJ/L-150724-2
# Certifier SUNIL D' is assigned to Aircraft DDB/L-160724
# Certifier OSMAN is assigned to Aircraft BMF/L-150724
# Certifier OSMAN is assigned to Aircraft BLS/L-150724
# Certifier OSMAN is assigned to Aircraft BLM/L-150724
# Certifier JAHANGIR is assigned to Aircraft ETA/L-150724
# Certifier JAHANGIR is assigned to Aircraft DDF/L-160724
# Certifier JAHANGIR is assigned to Aircraft BLU/L-150724-2
# Certifier MANI is assigned to Aircraft BMI/L-150724
# Certifier MANI is assigned to Aircraft BLK/L-150724
# Certifier MARK C. is assigned to Aircraft EIU/L-150724-3
# Certifier MARK C. is assigned to Aircraft BLW/L-150724
# Certifier MIRZA A is assigned to Aircraft XWA/L-150724
# Certifier MIRZA A is assigned to Aircraft BLT/L-150724
# Certifier KANTI is assigned to Aircraft EII/L-150724-4
# Certifier KANTI is assigned to Aircraft BNE/L-150724
# Certifier KANTI is assigned to Aircraft BLY/L-150724
# Certifier MUZAHMI is assigned to Aircraft EJA/L-150724-3
# Certifier MUZAHMI is assigned to Aircraft EIT/L-150724-2
# Certifier MUZAHMI is assigned to Aircraft EII/L-150724-3
# Certifier ALEXANDER is assigned to Aircraft EIN/L-150724-3
# Certifier SAMEER is assigned to Aircraft EIX/L-150724-3
# Certifier SAMEER is assigned to Aircraft EIA/L-150724-3
# Certifier SOROKIN is assigned to Aircraft ETP/L-150724
# Certifier SOROKIN is assigned to Aircraft ETE/L-160724
# Certifier LEWIS is assigned to Aircraft EIX/L-150724-2
# Certifier ISMAEEL is assigned to Aircraft EIV/L-150724-2
# Certifier MANSOUR is assigned to Aircraft EIY/L-150724-2
# Certifier MANSOUR is assigned to Aircraft EIS/L-150724-2

# %%
import pandas as pd

# Initialize lists to store the data
data = []
summary_data = []
total_cost_data = []

no_certification_assignments = []

for c in certifiers:
    num_aircraft_assigned = sum(assignment[c][a].varValue for a in aircraft_wp)
    assignment_cost = calculate_assignment_cost(num_aircraft_assigned)

    movement_cost = 0
    zone_change_cost = 0
    similar_departure_time_cost = 0
    similar_arrival_time_cost = 0
    overlapping_time_cost = 0
    assigned_aircraft = [a for a in aircraft_wp if assignment[c][a].varValue == 1]

    for i in range(len(assigned_aircraft)):
        for j in range(i + 1, len(assigned_aircraft)):
            a1 = assigned_aircraft[i]
            a2 = assigned_aircraft[j]
            movement_cost += movement_cost_matrix[(a1, a2)]
            zone_change_cost += calculate_zone_change_cost(
                aircraft_info[a1]["Bay"], aircraft_info[a2]["Bay"]
            )
            similar_departure_time_cost += calculate_similar_departure_time_cost(
                c,
                aircraft_info[a1]["Departure time"],
                aircraft_info[a2]["Departure time"],
            )
            similar_arrival_time_cost += calculate_similar_arrival_time_cost(
                c, aircraft_info[a1]["Arrival time"], aircraft_info[a2]["Arrival time"]
            )
            overlapping_time_cost += calculate_overlapping_time_cost(
                c,
                aircraft_info[a1]["Departure time"],
                aircraft_info[a1]["Arrival time"],
                aircraft_info[a2]["Departure time"],
                aircraft_info[a2]["Arrival time"],
                aircraft_info[a1]["Ground Time (minutes)"],
                aircraft_info[a2]["Ground Time (minutes)"],
            )

    certification_shift_quality_cost = sum(
        assignment[c][a].varValue
        * (
            calculate_certification_cost(c, a)
            + calculate_shift_leader_cost(c)
            + calculate_quality_control_cost(c)
        )
        for a in aircraft_wp
    )

    total_cost = (
        assignment_cost
        + movement_cost
        + zone_change_cost
        + similar_departure_time_cost
        + similar_arrival_time_cost
        + overlapping_time_cost
        + certification_shift_quality_cost
    )

    summary_data.append(
        {
            "Certifier": c,
            "Number of Aircraft Assigned": num_aircraft_assigned,
            "Total Cost": total_cost,
        }
    )

    for a in assigned_aircraft:
        certification_cost = calculate_certification_cost(c, a)
        data.append(
            {
                "Certifier": c,
                "Aircraft": a,
                "Number of Aircraft Assigned": num_aircraft_assigned,
                "Assignment Cost": assignment_cost,
                "Movement Cost": movement_cost,
                "Zone Change Cost": zone_change_cost,
                "Similar Departure Time Cost": similar_departure_time_cost,
                "Similar Arrival Time Cost": similar_arrival_time_cost,
                "Overlapping Time Cost": overlapping_time_cost,
                "Certification, Shift Leader, and Quality Control Cost": certification_shift_quality_cost,
                "Certification Cost": certification_cost,
            }
        )
        if certification_cost == 100000:
            no_certification_assignments.append((c, a))

# Print assignments without certifications
if no_certification_assignments:
    print("Assignments without proper certifications:")
    for certifier, aircraft in no_certification_assignments:
        print(
            f"  Certifier {certifier} is assigned to Aircraft {aircraft} without proper certification"
        )

# Print total cost
total_cost_value = value(problem.objective)
print(f"Total cost: {total_cost_value}")

# Create DataFrames
df = pd.DataFrame(data)
summary_df = pd.DataFrame(summary_data)
total_cost_df = pd.DataFrame(summary_data)

# Write to Excel
with pd.ExcelWriter("assignment_costs.xlsx") as writer:
    df.to_excel(writer, sheet_name="Detailed Costs", index=False)
    summary_df.to_excel(writer, sheet_name="Summary Assignments", index=False)
    total_cost_df.to_excel(writer, sheet_name="Total Cost per Certifier", index=False)

print("All costs and assignments have been saved to 'assignment_costs.xlsx'.")
# Out:
# Total cost: 11788.0
# All costs and assignments have been saved to 'assignment_costs.xlsx'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import numpy as np

# Prepare the data for Gantt chart
gantt_data = []

for c in certifiers:
    assigned_aircraft = [a for a in aircraft_wp if assignment[c][a].varValue == 1]
    for index, a in enumerate(assigned_aircraft):
        arrival_time = pd.to_datetime(aircraft_info[a]["Arrival time"])
        departure_time = pd.to_datetime(aircraft_info[a]["Departure time"])
        gantt_data.append(
            {
                "Certifier": c,
                "Aircraft": a,
                "Start": arrival_time,
                "Finish": departure_time,
                "Line": f"{c} - {a}",
            }
        )

gantt_df = pd.DataFrame(gantt_data)

# Convert the times to matplotlib's internal format
gantt_df["Start_num"] = mdates.date2num(gantt_df["Start"])
gantt_df["Finish_num"] = mdates.date2num(gantt_df["Finish"])
gantt_df["Duration"] = gantt_df["Finish_num"] - gantt_df["Start_num"]

# Find the earliest start time and latest finish time to set as the x-axis limit
earliest_start = gantt_df["Start"].min() - pd.Timedelta(hours=1)
latest_finish = gantt_df["Finish"].max() + pd.Timedelta(hours=1)

# Convert to matplotlib's internal format
earliest_start_num = mdates.date2num(earliest_start)
latest_finish_num = mdates.date2num(latest_finish)

# Create the Gantt chart
fig, ax = plt.subplots(figsize=(15, 10))

# Use a predefined list of distinct colors
colors = plt.cm.tab20(np.linspace(0, 1, 20))

# Shuffle the colors to avoid adjacent colors being too similar
np.random.shuffle(colors)

# Take only the unique certifiers
unique_certifiers = gantt_df["Certifier"].unique()


# Plot each assignment
color_dict = {
    certifier: colors[i % len(colors)] for i, certifier in enumerate(unique_certifiers)
}

for certifier in unique_certifiers:
    df_cert = gantt_df[gantt_df["Certifier"] == certifier]
    color = color_dict[certifier]
    for _, row in df_cert.iterrows():
        ax.barh(
            row["Line"],
            row["Duration"],
            left=row["Start_num"],
            align="center",
            color=color,
            label=row["Certifier"],
        )

# Remove duplicate labels in the legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())

# Format the x-axis to show date and time
ax.xaxis.set_major_formatter(mdates.DateFormatter("%d -- %H:%M"))
ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
ax.xaxis.set_minor_locator(mdates.HourLocator(interval=1))
ax.xaxis.set_major_formatter(DateFormatter("%d -- %H:%M"))

# Set x-axis limits
ax.set_xlim(earliest_start_num, latest_finish_num)

plt.xlabel("Time")
plt.ylabel("Certifier - Aircraft")
plt.title("Gantt Chart of Certifier Assignments")
plt.grid(True)

plt.xticks(rotation=90)
plt.tight_layout()

# Show the plot
plt.show()
